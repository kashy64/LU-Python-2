# %% [markdown]
# 1) Write a Python program to remove empty List from List.

# %%
test_list = [5, 6, [], 3, [], [], 9]

# %%
res = [ele for ele in test_list if ele != []]

# %%
print(res)
# Out:
# [5, 6, 3, 9]

# %% [markdown]
# Or Second Way

# %%
res = list(filter(None, test_list))

# %%
res
# Out:
# [5, 6, 3, 9]

# %% [markdown]
# 2) Write a Python program to remove all duplicates words from a given sentence

# %%
s = "Geeks for Geeks"
l = s.split() 
k = [] 
for i in l:   
    if (s.count(i)>1 and (i not in k)or s.count(i)==1): 
        k.append(i) 
print(' '.join(k))
# Out:
# Geeks for

# %%
l
# Out:
# ['Geeks', 'for', 'Geeks']

# %% [markdown]
# 3) Write a Python program to find all occurrences of a character in the given string

# %%
n=str(input("Enter the String:"))
# Out:
# Enter the String: Kashyap

# %%
x= 0
for i in n: 
    if i == 'a':
        x+=1

# %%
print("Count of letter 'a' is:",x)
# Out:
# Count of letter 'a' is: 2
